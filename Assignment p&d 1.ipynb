# %%
import numpy as np
import pandas as pd

# %%
Month = ['Jan','Feb','March','April','May','June','July','Aug','Sept','Oct','Nov','Dec']
numbers_of_date = np.arange(1,31)
np.random.seed(10)
score = np.random.randint(5000,500000,360)
score = score.reshape(30,12)

numbers_day= pd.DataFrame(data = score,index=numbers_of_date,columns=Month)
numbers_day
# Out:
#        Jan     Feb   March   April     May    June    July     Aug    Sept  \
# 1   350353  241669  361879  448712   98553  110595   14372  408417  304741
# 2   441218  145296  276433  191624  232818  361392  474494  250156  445691
# 3    56595  465854  303328   12290  431558  430505  329808  226028   30550
# 4   426965  479565  279445  405115  349473  186630  218645  172772  268510
# 5   237076  241865  396711   36545  334508   54435   33178  209893  377813
# 6   179840   25875  346660  413650  100448  340241   27543  221594  180568
# 7   297235   72217   96566  202767  290387   30372  437929  199004  319106
# 8   171533  351116  392143  372960   43744  211642  276724  340030  113834
# 9    56855  319365  211982  333950  286173  265842  196126  129427  437752
# 10  324550  334206  216129   29561  412119  318708  250992  139698  417397
# 11   56757  363312  492385  380497  422445  478728   22298   85407  104843
# ...

# %%
mean= [np.mean(numbers_day["Jan"]), np.mean(numbers_day["Feb"]),np.mean(numbers_day["May"]),np.mean(numbers_day["Aug"]), np.mean(numbers_day["Sept"])]
mean
# Out:
# [225492.86666666667,
#  243327.63333333333,
#  286499.06666666665,
#  235822.33333333334,
#  245405.46666666667]

# %%
numbers_day.loc['Max'] = pd.DataFrame.max(numbers_day[["Jan","Feb","March","April","May","June","July","Aug","Sept","Oct","Nov","Dec"]])

# %%
numbers_day
# Out:
#         Jan     Feb   March   April     May    June    July     Aug    Sept  \
# 1    350353  241669  361879  448712   98553  110595   14372  408417  304741
# 2    441218  145296  276433  191624  232818  361392  474494  250156  445691
# 3     56595  465854  303328   12290  431558  430505  329808  226028   30550
# 4    426965  479565  279445  405115  349473  186630  218645  172772  268510
# 5    237076  241865  396711   36545  334508   54435   33178  209893  377813
# 6    179840   25875  346660  413650  100448  340241   27543  221594  180568
# 7    297235   72217   96566  202767  290387   30372  437929  199004  319106
# 8    171533  351116  392143  372960   43744  211642  276724  340030  113834
# 9     56855  319365  211982  333950  286173  265842  196126  129427  437752
# 10   324550  334206  216129   29561  412119  318708  250992  139698  417397
# 11    56757  363312  492385  380497  422445  478728   22298   85407  104843
# ...

# %%
np.percentile(numbers_day["Feb"],20)
# Out:
# 134024.0

# %%
np.percentile(numbers_day["June"],50)
# Out:
# 275602.0

# %%
np.percentile(numbers_day["Dec"],75)
# Out:
# 370670.5

# %%
numbers_day['June'] - numbers_day['July']
# Out:
# 1      96223
# 2    -113102
# 3     100697
# 4     -32015
# 5      21257
# 6     312698
# 7    -407557
# 8     -65082
# 9      69716
# 10     67716
# 11    456430
# 12    -22046
# 13    213967
# 14   -251639
# 15    183569
# 16    315774
# 17     17731
# 18     61602
# 19    -13502
# 20     97830
# 21   -169613
# 22   -207736
# 23     14274
# 24    345457
# 25   -308872
# 26    254475
# 27    361661
# 28    434420
# 29    401298
# 30     -1310
# dtype: int32
